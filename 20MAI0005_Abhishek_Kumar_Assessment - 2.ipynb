# %% [markdown]
# # 20MAI0005_Abhishek_Kumar
# # Implementing KMeans and Agglomerative Clustering on Beverages Dataset

# %% [markdown]
# # 1. KMeans Clustering

# %%
#1 Importing the dataset
import pandas as pd
bev_df = pd.read_csv("bev.csv")
bev_df.head()
# Out:
#                    Name  Potassium  Sodium  Caffeine  Cost
# 0    new_england_coffee        144      15       4.7  0.43
# 1      post_alley_blend        151      19       4.9  0.43
# 2      stumpdown_coffee        157      15       0.9  0.48
# 3  bizzy_organic_coffee        170       7       5.2  0.73
# 4           indian_bean        152      11       5.0  0.77

# %%
import numpy as n
import seaborn as sn

#scatter plot
sn.lmplot("Name","Potassium",data=bev_df, fit_reg=False,height = 6)
sn.lmplot("Name","Sodium",data=bev_df, fit_reg=False,height = 6)
sn.lmplot("Name","Caffeine",data=bev_df, fit_reg=False,height = 6)
sn.lmplot("Name","Cost",data=bev_df, fit_reg=False,height = 6)

# %%
#2 Scaling the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_bev_df = scaler.fit_transform(bev_df[["Potassium","Sodium","Caffeine","Cost"]])
scaled_bev_df[0:5]
# Out:
# array([[ 0.38791334,  0.00779468,  0.43380786, -0.45682969],
#        [ 0.6250656 ,  0.63136906,  0.62241997, -0.45682969],
#        [ 0.82833896,  0.00779468, -3.14982226, -0.10269815],
#        [ 1.26876459, -1.23935408,  0.90533814,  1.66795955],
#        [ 0.65894449, -0.6157797 ,  0.71672602,  1.95126478]])

# %%
#3 Importing Kmeans
from sklearn.cluster import KMeans
clusters = KMeans(3)
clusters.fit(scaled_bev_df)
bev_df["clusterid"] = clusters.labels_

# %%
#4 Clusterwise data
bev_df[bev_df.clusterid == 0]
# Out:
#                      Name  Potassium  Sodium  Caffeine  Cost  clusterid
# 3    bizzy_organic_coffee        170       7       5.2  0.73          0
# 4             indian_bean        152      11       5.0  0.77          0
# 13  green_mountain_coffee        150      19       4.7  0.76          0
# 14            koffee_cuit        149       6       5.0  0.79          0

# %%
bev_df[bev_df.clusterid == 1]
# Out:
#                      Name  Potassium  Sodium  Caffeine  Cost  clusterid
# 0      new_england_coffee        144      15       4.7  0.43          1
# 1        post_alley_blend        151      19       4.9  0.43          1
# 5           jacobs_coffee        145      23       4.6  0.28          1
# 6   grounds_hounds_coffee        175      24       5.5  0.40          1
# 7      la_columbe_corisca        149      27       4.7  0.42          1
# 10         red_bay_coffee        140      18       4.6  0.44          1
# 16  irish_hazelnut_coffee        139      19       4.4  0.43          1
# 17         cremoso_coffee        144      24       4.9  0.43          1

# %%
bev_df[bev_df.clusterid == 2]
# Out:
#                    Name  Potassium  Sodium  Caffeine  Cost  clusterid
# 2      stumpdown_coffee        157      15       0.9  0.48          2
# 8   lavazza_super_crema         99      10       4.3  0.43          2
# 9           mount_hagen        113       8       3.7  0.40          2
# 11   peerless_wholebean        102      15       4.1  0.46          2
# 12  stone_street_coffee        135      11       4.2  0.50          2
# 15       caribou_coffee         68      15       2.3  0.38          2
# 18      davidoff_coffee         72       6       2.9  0.46          2
# 19            js_coffee         97       7       4.2  0.47          2

# %%
#5 plotting the clusters
markers = ['+','^','.']
sn.lmplot("Name","Potassium",data=bev_df, hue="clusterid",markers=markers,fit_reg=False,height = 6)
sn.lmplot("Name","Sodium",data=bev_df, hue="clusterid",markers=markers,fit_reg=False,height = 6)
sn.lmplot("Name","Caffeine",data=bev_df, hue="clusterid",markers=markers,fit_reg=False,height = 6)
sn.lmplot("Name","Cost",data=bev_df, hue="clusterid",markers=markers,fit_reg=False,height = 6)

# %% [markdown]
# # 2. Agglomerative Clustering

# %%
#1 Importing the dataset for Agglomerative Clustering
bev_df1 = pd.read_csv("bev.csv")
bev_df1.head()
# Out:
#                    Name  Potassium  Sodium  Caffeine  Cost
# 0    new_england_coffee        144      15       4.7  0.43
# 1      post_alley_blend        151      19       4.9  0.43
# 2      stumpdown_coffee        157      15       0.9  0.48
# 3  bizzy_organic_coffee        170       7       5.2  0.73
# 4           indian_bean        152      11       5.0  0.77

# %%
#2 Scaling the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_bev_df1 = scaler.fit_transform(bev_df1[["Potassium","Sodium","Caffeine","Cost"]])
scaled_bev_df1[0:5]
# Out:
# array([[ 0.38791334,  0.00779468,  0.43380786, -0.45682969],
#        [ 0.6250656 ,  0.63136906,  0.62241997, -0.45682969],
#        [ 0.82833896,  0.00779468, -3.14982226, -0.10269815],
#        [ 1.26876459, -1.23935408,  0.90533814,  1.66795955],
#        [ 0.65894449, -0.6157797 ,  0.71672602,  1.95126478]])

# %%
#3 Importinh Agglpmerative Clustering
from sklearn.cluster import AgglomerativeClustering
cluster1 = AgglomerativeClustering(n_clusters=3)
cluster1.fit(scaled_bev_df1)
bev_df1["clusterid1"] = cluster1.labels_

# %%
#4 Clusterwise data
bev_df1[bev_df1.clusterid1 == 0]
# Out:
#                    Name  Potassium  Sodium  Caffeine  Cost  clusterid1
# 2      stumpdown_coffee        157      15       0.9  0.48           0
# 8   lavazza_super_crema         99      10       4.3  0.43           0
# 9           mount_hagen        113       8       3.7  0.40           0
# 11   peerless_wholebean        102      15       4.1  0.46           0
# 12  stone_street_coffee        135      11       4.2  0.50           0
# 15       caribou_coffee         68      15       2.3  0.38           0
# 18      davidoff_coffee         72       6       2.9  0.46           0
# 19            js_coffee         97       7       4.2  0.47           0

# %%
bev_df1[bev_df1.clusterid1 == 1]
# Out:
#                      Name  Potassium  Sodium  Caffeine  Cost  clusterid1
# 0      new_england_coffee        144      15       4.7  0.43           1
# 1        post_alley_blend        151      19       4.9  0.43           1
# 5           jacobs_coffee        145      23       4.6  0.28           1
# 6   grounds_hounds_coffee        175      24       5.5  0.40           1
# 7      la_columbe_corisca        149      27       4.7  0.42           1
# 10         red_bay_coffee        140      18       4.6  0.44           1
# 16  irish_hazelnut_coffee        139      19       4.4  0.43           1
# 17         cremoso_coffee        144      24       4.9  0.43           1

# %%
bev_df1[bev_df1.clusterid1 == 2]
# Out:
#                      Name  Potassium  Sodium  Caffeine  Cost  clusterid1
# 3    bizzy_organic_coffee        170       7       5.2  0.73           2
# 4             indian_bean        152      11       5.0  0.77           2
# 13  green_mountain_coffee        150      19       4.7  0.76           2
# 14            koffee_cuit        149       6       5.0  0.79           2

# %%
#5 plotting the clusters
markers = ['+','^','.']
sn.lmplot("Name","Potassium",data=bev_df1, hue="clusterid1",markers=markers,fit_reg=False,height = 6)
sn.lmplot("Name","Sodium",data=bev_df1, hue="clusterid1",markers=markers,fit_reg=False,height = 6)
sn.lmplot("Name","Caffeine",data=bev_df1, hue="clusterid1",markers=markers,fit_reg=False,height = 6)
sn.lmplot("Name","Cost",data=bev_df1, hue="clusterid1",markers=markers,fit_reg=False,height = 6)

# %% [markdown]
# ### Conclusion:
#
# 1. Both Agglomerative and K-means clustering produced the same clusters.
# 2. Determining the value of exact value of K would help in evaluating the algorithms better.
# 3. Since the clustering was performed after scaling we can be sure of the fact that all the variables were taken into account.
# 4. For the dataset given, both K-means and Agglomerative returned the same clusters for K=3.

# %% [markdown]
# Note: Madam as you can see the graph cannot read properly any alternative way to make it better
