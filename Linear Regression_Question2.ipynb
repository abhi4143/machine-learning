# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %%
# Read the csv file using 'read_csv'

data = pd.read_csv('loan.csv')
data
# Out:
#       customer_id  disbursed_amount  interest market     employment  \
# 0               0           23201.5   15.4840      C        Teacher
# 1               1            7425.0   11.2032      B     Accountant
# 2               2           11150.0    8.5100      A   Statistician
# 3               3            7600.0    5.8656      A          Other
# 4               4           31960.0   18.7392      E     Bus driver
# ...           ...               ...       ...    ...            ...
# 9995         9995           23750.0   11.0019      B  Civil Servant
# 9996         9996           11880.0   10.4923      B  Civil Servant
# 9997         9997           19950.0    8.4364      B     Accountant
# 9998         9998            4850.0   13.6409      C     Bus driver
# 9999         9999           25584.0   17.1456      D     Accountant
#
#      time_employed householder    income date_issued  target  \
# 0        <=5 years        RENT   84600.0  2013-06-11       0
# ...

# %%
# Check the number of rows and columns in the dataframe

data.shape
# Out:
# (10000, 14)

# %%
# Check the column-wise info of the dataframe

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             10000 non-null  int64
#  1   disbursed_amount        10000 non-null  float64
#  2   interest                10000 non-null  float64
#  3   market                  10000 non-null  object
#  4   employment              9389 non-null   object
#  5   time_employed           9471 non-null   object
#  6   householder             10000 non-null  object
#  7   income                  10000 non-null  float64
#  8   date_issued             10000 non-null  object
#  9   target                  10000 non-null  int64
#  10  loan_purpose            10000 non-null  object
#  11  number_open_accounts    10000 non-null  float64
#  12  date_last_payment       10000 non-null  object
#  13  number_credit_lines_12  238 non-null    float64
# ...

# %%
# Get a summary of the dataframe using 'describe()'

data.describe()
# Out:
#        customer_id  disbursed_amount      interest        income  \
# count  10000.00000      10000.000000  10000.000000  1.000000e+04
# mean    4999.50000      14132.275500     12.678819  7.157229e+04
# std     2886.89568       8058.310311      4.214989  5.286105e+04
# min        0.00000        910.000000      4.841200  0.000000e+00
# 25%     2499.75000       7840.000000      9.490000  4.365000e+04
# 50%     4999.50000      12375.000000     12.396900  6.045000e+04
# 75%     7499.25000      19200.000000     15.475500  8.536000e+04
# max     9999.00000      35000.000000     27.880000  2.185000e+06
#
#              target  number_open_accounts  number_credit_lines_12
# count  10000.000000          10000.000000              238.000000
# mean       0.011700             12.516300                1.785714
# std        0.107537              5.402615                1.197873
# min        0.000000              1.000000                0.000000
# ...

# %%
#1. Display the mean of any two variables with continuous values
continuous_value=[c for c in data.columns if data[c].dtype!='O']
print(continuous_value)
print("Mean of disbursed_amount column is ",data['disbursed_amount'].mean())
print(" Mean of intrest column is ",data['interest'].mean())
# Out:
# ['customer_id', 'disbursed_amount', 'interest', 'income', 'target', 'number_open_accounts', 'number_credit_lines_12']
# Mean of disbursed_amount column is  14132.2755
#  Mean of intrest column is  12.678819440000039

# %%
#2. Print the number of discrete variables
categoric_value=[c for c in data.columns if data[c].dtype=='O']
print(categoric_value)
print("Number of discreate type columns are ",len(categoric_value))
# Out:
# ['market', 'employment', 'time_employed', 'householder', 'date_issued', 'loan_purpose', 'date_last_payment']
# Number of discreate type columns are  7

# %%
#3. Display the unique values of two variables with discrete values
print("The values in market column are ",data['market'].unique())
print("The values in employment column are ",data['employment'].unique())
# Out:
# The values in market column are  ['C' 'B' 'A' 'E' 'D']
# The values in employment column are  ['Teacher' 'Accountant' 'Statistician' 'Other' 'Bus driver' 'Secretary'
#  'Software developer' 'Nurse' 'Taxi driver' nan 'Civil Servant' 'Dentist']

# %%
#4.Question 4
data['date_issued']=pd.to_datetime(data['date_issued']) #change to date typedata
print(data[['date_issued']].dtypes)
# Out:
# date_issued    datetime64[ns]
# dtype: object

# %%
#Getting the count of the month
data['month_issued']=data['date_issued'].dt.month
data['month_issued']
# Out:
# 0        6
# 1        5
# 2       10
# 3        8
# 4        7
#         ..
# 9995     1
# 9996     3
# 9997     4
# 9998    11
# 9999     1
# Name: month_issued, Length: 10000, dtype: int64

# %%
for x in range(10000):
    if data['month_issued'][x]==1:
        data['month_issued'][x]='Jan'
    elif data['month_issued'][x]==2:
        data['month_issued'][x]='Feb'
    elif data['month_issued'][x]==3:
        data['month_issued'][x]='Mar'
    elif data['month_issued'][x]==4:
        data['month_issued'][x]='Apr'
    elif data['month_issued'][x]==5:
        data['month_issued'][x]='May'
    elif data['month_issued'][x]==6:
        data['month_issued'][x]='Jun'
    elif data['month_issued'][x]==7:
        data['month_issued'][x]='Jul'
    elif data['month_issued'][x]==8:
        data['month_issued'][x]='Aug'
    elif data['month_issued'][x]==9:
        data['month_issued'][x]='Sep'
    elif data['month_issued'][x]==10:
        data['month_issued'][x]='Oct'
    elif data['month_issued'][x]==11:
        data['month_issued'][x]='Nov'
    elif data['month_issued'][x]==12:
        data['month_issued'][x]='Dec'

# %%
#Converting into dictionary
data['month_issued']
data['month_issued'].value_counts()
month_issuesd_dict=data['month_issued'].value_counts().to_dict()
month_issuesd_dict
# Out:
# {'Oct': 1277,
#  'Jul': 1066,
#  'Nov': 1017,
#  'Dec': 882,
#  'Aug': 852,
#  'Apr': 816,
#  'May': 749,
#  'Sep': 734,
#  'Jan': 700,
#  'Jun': 700,
#  'Mar': 623,
#  'Feb': 584}

# %%
#4. Display the Month with most of loans issued date
# function to return key for any value in a dictionary

def get_key(val):
    for key, value in month_issuesd_dict.items():
         if val == value:
             return key
    return "key doesn't exist"
max_issues=max(data['month_issued'].value_counts())
print("Month in which maximum number of loan issued is",get_key(max_issues))
print(" Number of issues loan on that month is ",max_issues)
# Out:
# Month in which maximum number of loan issued is Oct
#  Number of issues loan on that month is  1277

# %%
#Qustion number 5
data['employment'].value_counts()
# Out:
# Civil Servant         884
# Nurse                 880
# Bus driver            874
# Other                 863
# Teacher               861
# Statistician          852
# Accountant            852
# Secretary             846
# Dentist               844
# Taxi driver           825
# Software developer    808
# Name: employment, dtype: int64

# %%
data_emp=data['employment'].value_counts()

# %%
#5. Display the count of ‘Teacher’ who are ‘Owners
#Converting into dictionary
data_emp_dict=data_emp.to_dict()
data_emp_dict
print("Number of owners who have Teacher profesion is ",data_emp_dict['Teacher'])
# Out:
# Number of owners who have Teacher profesion is  861

# %%
#6. Display the ‘Employment’ of customers who mostly ‘Rent'
type(data['employment'])
# Out:
# pandas.core.series.Series

# %%
empl=data['employment'].to_list()
type(data.shape)
# Out:
# tuple

# %%
on_rent=[]
for i in range(data.shape[0]):
    if data['householder'][i]=='RENT':
        on_rent.append(empl[i])
empl
# Out:
# ['Teacher',
#  'Accountant',
#  'Statistician',
#  'Other',
#  'Bus driver',
#  'Statistician',
#  'Secretary',
#  'Software developer',
#  'Statistician',
#  'Nurse',
#  'Accountant',
#  'Taxi driver',
#  'Other',
#  nan,
#  'Taxi driver',
#  'Accountant',
#  'Secretary',
#  nan,
#  'Bus driver',
#  'Accountant',
#  'Civil Servant',
#  'Statistician',
#  'Civil Servant',
#  'Teacher',
#  'Civil Servant',
#  'Dentist',
#  nan,
#  'Civil Servant',
#  'Other',
#  'Accountant',
#  'Dentist',
#  'Accountant',
#  'Other',
#  'Teacher',
#  'Civil Servant',
#  'Taxi driver',
#  'Accountant',
#  'Software developer',
#  'Nurse',
#  'Dentist',
#  'Secretary',
#  'Accountant',
#  'Taxi driver',
#  'Teacher',
#  'Secretary',
#  'Teacher',
#  'Civil Servant',
#  'Software developer',
#  'Civil Servant',
#  'Accountant',
#  'Nurse',
#  'Statistician',
#  'Civil Servant',
#  'Taxi driver',
#  'Statistician',
#  'Statistician',
#  'Accountant',
#  'Bus driver',
#  'Bus driver',
#  'Statistician',
# ...

# %%
#See the total count
len(on_rent)
# Out:
# 4055

# %%
def CountFrequency(my_list): 
      
   # Creating an empty dictionary  
   count_on_rent = {} 
   for i in on_rent: 
    count_on_rent[i] = count_on_rent.get(i, 0) + 1
   return count_on_rent 
  
print(CountFrequency(on_rent))
# Out:
# {'Teacher': 371, 'Statistician': 342, 'Other': 353, 'Bus driver': 360, 'Secretary': 355, 'Software developer': 315, 'Nurse': 358, 'Accountant': 322, 'Civil Servant': 371, 'Dentist': 355, 'Taxi driver': 316, nan: 237}
